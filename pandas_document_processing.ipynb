# %%
import numpy as np
import pandas as pd
import re
import nltk

# %%
doc = pd.read_csv('/home/dboyliao/Documents/train.tsv', sep="\t")

# %%
doc
# Out:
#         PhraseId  SentenceId  \
# 0              1           1
# 1              2           1
# 2              3           1
# 3              4           1
# 4              5           1
# 5              6           1
# 6              7           1
# 7              8           1
# 8              9           1
# 9             10           1
# 10            11           1
# 11            12           1
# 12            13           1
# 13            14           1
# 14            15           1
# 15            16           1
# 16            17           1
# 17            18           1
# 18            19           1
# 19            20           1
# 20            21           1
# 21            22           1
# 22            23           1
# 23            24           1
# 24            25           1
# 25            26           1
# 26            27           1
# 27            28           1
# 28            29           1
# 29            30           1
# ...          ...         ...
# ...

# %%
token_1 = np.array(map(lambda sent: re.split("\s+", sent), doc.Phrase[doc.Sentiment==1]))

# %%
token_2 = np.array(map(lambda sent: re.split("\s+", sent), doc.Phrase[doc.Sentiment==2]))

# %%
token_3 = np.array(map(lambda sent: re.split("\s+", sent), doc.Phrase[doc.Sentiment==3]))

# %%
token_4 = np.array(map(lambda sent: re.split("\s+", sent), doc.Phrase[doc.Sentiment==4]))

# %%
token_5 = np.array(map(lambda sent: re.split("\s+", sent), doc.Phrase[doc.Sentiment==5]))

# %%
token_1
# Out:
# array([ ['A', 'series', 'of', 'escapades', 'demonstrating', 'the', 'adage', 'that', 'what', 'is', 'good', 'for', 'the', 'goose', 'is', 'also', 'good', 'for', 'the', 'gander', ',', 'some', 'of', 'which', 'occasionally', 'amuses', 'but', 'none', 'of', 'which', 'amounts', 'to', 'much', 'of', 'a', 'story', '.'],
#        ['the', 'gander', ',', 'some', 'of', 'which', 'occasionally', 'amuses', 'but', 'none', 'of', 'which', 'amounts', 'to', 'much', 'of', 'a', 'story'],
#        ['but', 'none', 'of', 'which', 'amounts', 'to', 'much', 'of', 'a', 'story'],
#        ..., ['sadness', 'and', 'obsession'], ['sadness', 'and'],
#        ['forced', 'avuncular', 'chortles']], dtype=object)

# %%
token_2
# Out:
# array([ ['A', 'series', 'of', 'escapades', 'demonstrating', 'the', 'adage', 'that', 'what', 'is', 'good', 'for', 'the', 'goose'],
#        ['A', 'series'], ['A'], ..., ['Hearst', "'s"], ['avuncular'],
#        ['chortles']], dtype=object)

# %%
np.hstack([token_1, token_2, token_3, token_4, token_5])
# Out:
# array([ ['A', 'series', 'of', 'escapades', 'demonstrating', 'the', 'adage', 'that', 'what', 'is', 'good', 'for', 'the', 'goose', 'is', 'also', 'good', 'for', 'the', 'gander', ',', 'some', 'of', 'which', 'occasionally', 'amuses', 'but', 'none', 'of', 'which', 'amounts', 'to', 'much', 'of', 'a', 'story', '.'],
#        ['the', 'gander', ',', 'some', 'of', 'which', 'occasionally', 'amuses', 'but', 'none', 'of', 'which', 'amounts', 'to', 'much', 'of', 'a', 'story'],
#        ['but', 'none', 'of', 'which', 'amounts', 'to', 'much', 'of', 'a', 'story'],
#        ..., ['with', 'universal', 'appeal'],
#        ['really', 'do', 'a', 'great', 'job', 'of', 'anchoring', 'the', 'characters', 'in', 'the', 'emotional', 'realities', 'of', 'middle', 'age', '.'],
#        ['a', 'great', 'job', 'of', 'anchoring', 'the', 'characters', 'in', 'the', 'emotional', 'realities', 'of', 'middle', 'age']], dtype=object)

# %%
a = pd.Series([1,5,7,9], index=['a', 'b', 'c', 'd'])

# %%
b = pd.Series([2,5,7], index=['a', 'c', 'f'])

# %%
a
# Out:
# a    1
# b    5
# c    7
# d    9
# dtype: int64

# %%
b
# Out:
# a    2
# c    5
# f    7
# dtype: int64

# %%
pd.concat([a, b], axis=1)
# Out:
#     0   1
# a   1   2
# b   5 NaN
# c   7   5
# d   9 NaN
# f NaN   7

# %%
pd.concat([a, b], axis=0)
# Out:
# a    1
# b    5
# c    7
# d    9
# a    2
# c    5
# f    7
# dtype: int64

# %%
c = pd.concat([a, b], axis=1)

# %%
c2 = c.T

# %%
c2
# Out:
#    a   b  c   d   f
# 0  1   5  7   9 NaN
# 1  2 NaN  5 NaN   7

# %%
label = pd.Series(['T', 'F'], index=[0,1], name='label')

# %%
pd.concat([c2, label], axis=1)
# Out:
#    a   b  c   d   f label
# 0  1   5  7   9 NaN     T
# 1  2 NaN  5 NaN   7     F

# %%
b2 = pd.Series(['a', 'c', 'f'], index=[2,5,7])

# %%
b2
# Out:
# 2    a
# 5    c
# 7    f
# dtype: object

# %%
a1 = pd.DataFrame(a)

# %%
b1 = pd.DataFrame(b)

# %%
a1 + b1
# Out:
#     0
# a   3
# b NaN
# c  12
# d NaN
# f NaN

# %%
pwd
# Out:
# u'/home/dboyliao'

# %%
a2 = a.to_sparse()

# %%
b2 = b.to_sparse()

# %%
a2
# Out:
# a    1
# b    5
# c    7
# d    9
# dtype: int64
# BlockIndex
# Block locations: array([0], dtype=int32)
# Block lengths: array([4], dtype=int32)

# %%
b2
# Out:
# a    2
# c    5
# f    7
# dtype: int64
# BlockIndex
# Block locations: array([0], dtype=int32)
# Block lengths: array([3], dtype=int32)

# %%
pd.concat([a2, b2], axis=1)
# Out:
#     0   1
# a   1   2
# b   5 NaN
# c   7   5
# d   9 NaN
# f NaN   7

# %%
from scipy.sparse import hstack

# %%
c2 = hstack((a2,b2))

# %%
c2.todense()
# Out:
# matrix([[1, 5, 7, 9, 2, 5, 7]])
